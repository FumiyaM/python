# %%
#URLの入力
URL='https://keiba.rakuten.co.jp/race_performance/list/RACEID/201905040304020111'
list = URL.split("/")
list[-1]
# Out:
# '201905040304020111'

# %%
import numpy as np
import selenium
from selenium import webdriver
browser = webdriver.Chrome()
browser.implicitly_wait(5)
browser.get(URL)

# %%
#馬名
kekka=browser.find_element_by_id('oddsField').find_elements_by_class_name('horse')
kekka[1].text
#馬数の取得
arr_2d = np.array(kekka)
umalen=arr_2d.size-1
umalen
# Out:
# 8

# %%
#urls=browser.find_element_by_id('oddsField').find_elements_by_css_selector("a")[9].get_attribute("href")
#urls

# %%
urlsets=[['' for i in range(200)] for j in range(2000)]
for j in range(0,umalen):
    urlsets[j]=browser.find_element_by_id('oddsField').find_elements_by_css_selector("a")[j].get_attribute("href")

# %%
#urlsets[9]

# %%
#browser.get(urls)

# %%
#r=browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_elements_by_class_name('name')
#len(r)

# %%
#browser.get(urlsets[6])
#browser.get(browser.find_elements_by_class_name('mainHorse')[1].find_elements_by_css_selector("a")[0].get_attribute("href"))

# %%
#本番
times = [['' for i in range(umalen*16)] for j in range(2000)]
#for j in range(0,len(uname.text)-1):
for j in range(0,umalen):
   # browser.implicitly_wait(2)
    #browser.get(browser.find_elements_by_class_name('mainHorse')[j].find_elements_by_css_selector("a")[0].get_attribute("href"))
    browser.get(urlsets[j])
    browser.implicitly_wait(5)
    r=browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_elements_by_class_name('name')

    for k in range(1,17):
            for r1 in range(1,len(r)+1):
                c=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[{s1}]/td[{s2}]'.format(s1=r1,s2=k))[0].text
                times[r1-1][16*j+k-1]=c

# %%
        
import pandas as pd
df = pd.DataFrame()
df_datas = pd.DataFrame(times)
df_datas
colm=[umalen*16]
#df_datas.columns = ['日付', '競馬場', 'R', 'レース名','距離','馬場\n天気','馬番','人気','着順','タイム','差','上3F','馬体重','騎手','負担重量','調教師']*umalen
for k in range(umalen):
    colm[k*16:k*16+15]=['着順{}＠本レース'.format(k+1), '競馬場', 'R', 'レース名','距離','馬場\n天気','馬番','人気','着順','タイム','差','上3F','馬体重','騎手','負担重量','調教師']

df_datas.columns=colm
#tdf_datas=  df_datas.split('\n')
df_datas
df_datas.to_csv('ばんえい結果馬情報{}.csv'.format(list[-1]),index=False, encoding='utf_8_sig')

# %% [markdown]
# ### ここまで

# %%
###メインの本文作成
for j in range(0,len(uname.text)-1):
    browser.implicitly_wait(5)
    browser.get(browser.find_elements_by_class_name('mainHorse')[j].find_elements_by_css_selector("a")[0].get_attribute("href"))
    r=browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_elements_by_class_name('name')
    #len(r)
    times = [['' for i in range(400)] for j in range(2000)]
    for k in range(1,17):
        for r1 in range(1,len(r)+1):
            c=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[{s1}]/td[{s2}]'.format(s1=r1,s2=k))[0].text
            times[r1-1][16*j+k]=c
            
        
import pandas as pd
df = pd.DataFrame()
df_datas = pd.DataFrame(times)
df_datas

#df_datas.columns = ['日付', '競馬場', 'R', 'レース名','距離','馬場\n天気','馬番','人気','着順','タイム','差','上3F','馬体重','騎手','負担重量','調教師']
#tdf_datas=  df_datas.split('\n')
df_datas
df_datas.to_csv('ばんえい馬情報1.csv',index=False, encoding='utf_8_sig')

# %%
import pandas as pd
df = pd.DataFrame()
df_datas = pd.DataFrame(times)
df_datas

# %%
r=browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_elements_by_class_name('name')
len(r)
times = [['' for i in range(16)] for j in range(2000)]
for k in range(1,17):
    for r1 in range(1,len(r)+1):
        c=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[{s1}]/td[{s2}]'.format(s1=r1,s2=k))[0].text
        times[r1-1][k-1]=c
        
import pandas as pd
df = pd.DataFrame()
df_datas = pd.DataFrame(times)
df_datas
df_datas.columns = ['日付', '競馬場', 'R', 'レース名','距離','馬場\n天気','馬番','人気','着順','タイム','差','上3F','馬体重','騎手','負担重量','調教師']
#tdf_datas=  df_datas.split('\n')
df_datas
df_datas.to_csv('ばんえい馬情報1.csv',index=False, encoding='utf_8_sig')

# %%
len(df_datas)

# %%
times = [['' for i in range(16)] for j in range(30)]
for k in range(1,17):
    for r1 in range(1,len(r)+1):
        c=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[{s1}]/td[{s2}]'.format(s1=r1,s2=k))[0].text
        times[r1-1][k-1]=c

# %%
times
# Out:
# [['2019/05/03',
#   '高知',
#   '6',
#   '奥村伊藤の特別Ｃ３\u3000－１８\n\n[過去映像]',
#   'ダ1300',
#   '重\n晴',
#   '1',
#   '1',
#   '2/8',
#   '1:24.0',
#   '0.1',
#   '39.3',
#   '482',
#   '永森大',
#   '54.0',
#   '雑賀正'],
#  ['2019/04/21',
#   '高知',
#   '12',
#   'ファイナルレースＣ３\u3000－２１\n\n[過去映像]',
#   'ダ1300',
#   '稍重\n晴',
#   '7',
#   '2',
#   '1/12',
#   '1:26.3',
#   '1.0',
#   '41.4',
#   '483',
#   '永森大',
#   '54.0',
#   '雑賀正'],
#  ['2019/03/31',
#   '高知',
#   '5',
#   '祝・洋一４０周年特別Ｃ１\u3000－３\n\n[過去映像]',
#   'ダ1400',
#   '重\n晴',
#   '8',
#   '6',
#   '9/12',
#   '1:34.1',
#   '0.9',
#   '42.7',
#   '473',
#   '永森大',
#   '54.0',
#   '雑賀正'],
#  ['2019/03/21',
#   '高知',
#   '2',
#   'Ｃ１－３Ｃ１\u3000－３\n\n[過去映像]',
#   'ダ1600',
#   '不良\n曇',
#   '2',
#   '4',
#   '5/8',
#   '1:46.6',
#   '1.4',
#   '43.1',
#   '470',
#   '永森大',
#   '54.0',
#   '雑賀正'],
#  ['2019/02/28',
#   '園田',
#   '9',
#   'Ｂ２Ｂ２\u3000４歳以上特別\n\n[過去映像]',
#   'ダ1230',
#   '重\n曇',
#   '8',
#   '11',
#   '12/12',
#   '1:21.6',
#   '2.9',
# ...

# %%
import pandas as pd
df = pd.DataFrame()
df_datas = pd.DataFrame(times)
df_datas
# Out:
#             0    1   2                                     3      4       5   \
# 0   2019/05/03   高知   6               奥村伊藤の特別Ｃ３　－１８\n\n[過去映像]  ダ1300    重\n晴
# 1   2019/04/21   高知  12              ファイナルレースＣ３　－２１\n\n[過去映像]  ダ1300   稍重\n晴
# 2   2019/03/31   高知   5             祝・洋一４０周年特別Ｃ１　－３\n\n[過去映像]  ダ1400    重\n晴
# 3   2019/03/21   高知   2                   Ｃ１－３Ｃ１　－３\n\n[過去映像]  ダ1600   不良\n曇
# 4   2019/02/28   園田   9                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230    重\n曇
# 5   2019/02/05   園田   9                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230   稍重\n晴
# 6   2019/01/17   園田  12                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230    良\n晴
# 7   2018/12/30   園田  10                 Ｂ２Ｂ２　３歳以上特別\n\n[過去映像]  ダ1400   稍重\n晴
# 8   2018/08/10   園田  10  デイリースポーツオンライン特別Ｂ１Ｂ１　３歳以上特別\n\n[過去映像]  ダ1400    良\n晴
# 9   2018/07/18   園田  11       西脇市日本のへそ特別Ｂ１Ｂ１　３歳以上特別\n\n[過去映像]  ダ1230    良\n晴
# 10  2018/06/15   園田  12                 Ｂ１Ｂ１　４歳以上特別\n\n[過去映像]  ダ1400   稍重\n曇
# ...

# %%
df_datas.columns = ['日付', '競馬場', 'R', 'レース名','距離','馬場\n天気','馬番','人気','着順','タイム','差','上3F','馬体重','騎手','負担重量','調教師']
#tdf_datas=  df_datas.split('\n')
df_datas
# Out:
#             日付  競馬場   R                                  レース名     距離  馬場\n天気  \
# 0   2019/05/03   高知   6               奥村伊藤の特別Ｃ３　－１８\n\n[過去映像]  ダ1300    重\n晴
# 1   2019/04/21   高知  12              ファイナルレースＣ３　－２１\n\n[過去映像]  ダ1300   稍重\n晴
# 2   2019/03/31   高知   5             祝・洋一４０周年特別Ｃ１　－３\n\n[過去映像]  ダ1400    重\n晴
# 3   2019/03/21   高知   2                   Ｃ１－３Ｃ１　－３\n\n[過去映像]  ダ1600   不良\n曇
# 4   2019/02/28   園田   9                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230    重\n曇
# 5   2019/02/05   園田   9                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230   稍重\n晴
# 6   2019/01/17   園田  12                 Ｂ２Ｂ２　４歳以上特別\n\n[過去映像]  ダ1230    良\n晴
# 7   2018/12/30   園田  10                 Ｂ２Ｂ２　３歳以上特別\n\n[過去映像]  ダ1400   稍重\n晴
# 8   2018/08/10   園田  10  デイリースポーツオンライン特別Ｂ１Ｂ１　３歳以上特別\n\n[過去映像]  ダ1400    良\n晴
# 9   2018/07/18   園田  11       西脇市日本のへそ特別Ｂ１Ｂ１　３歳以上特別\n\n[過去映像]  ダ1230    良\n晴
# 10  2018/06/15   園田  12                 Ｂ１Ｂ１　４歳以上特別\n\n[過去映像]  ダ1400   稍重\n曇
# ...

# %%
df_datas.to_csv('ばんえい馬情報1.csv',index=False, encoding='utf_8_sig')

# %%
times = []
#for i in range(1,17)
for r1 in range(1,len(r)+1):
        c=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[{}]/td[10]'.format(r1))[0].text
        times.append(c)

# %%
times
# Out:
# ['1:24.0',
#  '1:26.3',
#  '1:34.1',
#  '1:46.6',
#  '1:21.6',
#  '1:23.2',
#  '1:22.3',
#  '1:32.4',
#  '1:32.9',
#  '1:21.8',
#  '1:33.2',
#  '1:26.4',
#  '1:14.5',
#  '1:11.8',
#  '1:17.0',
#  '1:09.8',
#  '1:08.7',
#  '1:13.7',
#  '1:12.0',
#  '1:09.8',
#  '1:11.1',
#  '1:22.6',
#  '1:10.9',
#  '1:11.7']

# %%
browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_element_by_tag_name('tr').text
# Out:
# '2019/05/03 高知 6\n奥村伊藤の特別Ｃ３\u3000－１８\n\n[過去映像]\nダ1300 重\n晴 1 1 2/8 1:24.0 0.1 39.3 482 永森大 54.0 雑賀正'

# %%
browser.find_elements_by_class_name('contentsTable')[1].find_elements_by_class_name('horseHistory')[1].find_element_by_tag_name("tr").size
# Out:
# {'height': 39, 'width': 949}

# %%
browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody')[0].find_element_by_tag_name("tr").text
# Out:
# '2019/05/03 高知 6\n奥村伊藤の特別Ｃ３\u3000－１８\n\n[過去映像]\nダ1300 重\n晴 1 1 2/8 1:24.0 0.1 39.3 482 永森大 54.0 雑賀正'

# %%
browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[1]')[0].text
# Out:
# '2019/05/03 高知 6\n奥村伊藤の特別Ｃ３\u3000－１８\n\n[過去映像]\nダ1300 重\n晴 1 1 2/8 1:24.0 0.1 39.3 482 永森大 54.0 雑賀正'

# %%
browser.find_elements_by_xpath("//*[@id="mainContainer"]/div[2]/div[3]/table/tbody").find_element_by_tag_name("tr").size();
# Out:
#   File "<ipython-input-44-74d0321974b8>", line 1
#     browser.find_elements_by_xpath("//*[@id="mainContainer"]/div[2]/div[3]/table/tbody").find_element_by_tag_name("tr").size();
#                                                          ^
# SyntaxError: invalid syntax

# %%
b=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody/tr[1]/td[10]')
b[0].text
# Out:
# '1:24.0'

# %%
a=browser.find_elements_by_xpath('/div[2]/div[3]/table/tbody')
a= a[0].text
table_data=  a.split('\n')
table_data
# Out:
# []

# %%
a=browser.find_elements_by_xpath('//*[@id="mainContainer"]/div[2]/div[3]/table/tbody')
a= a[0].text
table_data=  a.split('\n')
table_data
# Out:
# ['2019/05/03 高知 6',
#  '奥村伊藤の特別Ｃ３\u3000－１８',
#  '',
#  '[過去映像]',
#  'ダ1300 重',
#  '晴 1 1 2/8 1:24.0 0.1 39.3 482 永森大 54.0 雑賀正',
#  '2019/04/21 高知 12',
#  'ファイナルレースＣ３\u3000－２１',
#  '',
#  '[過去映像]',
#  'ダ1300 稍重',
#  '晴 7 2 1/12 1:26.3 1.0 41.4 483 永森大 54.0 雑賀正',
#  '2019/03/31 高知 5',
#  '祝・洋一４０周年特別Ｃ１\u3000－３',
#  '',
#  '[過去映像]',
#  'ダ1400 重',
#  '晴 8 6 9/12 1:34.1 0.9 42.7 473 永森大 54.0 雑賀正',
#  '2019/03/21 高知 2',
#  'Ｃ１－３Ｃ１\u3000－３',
#  '',
#  '[過去映像]',
#  'ダ1600 不良',
#  '曇 2 4 5/8 1:46.6 1.4 43.1 470 永森大 54.0 雑賀正',
#  '2019/02/28 園田 9',
#  'Ｂ２Ｂ２\u3000４歳以上特別',
#  '',
#  '[過去映像]',
#  'ダ1230 重',
#  '曇 8 11 12/12 1:21.6 2.9 41.6 476 竹村達 54.0 盛本信',
#  '2019/02/05 園田 9',
#  'Ｂ２Ｂ２\u3000４歳以上特別',
#  '',
#  '[過去映像]',
#  'ダ1230 稍重',
#  '晴 7 10 9/12 1:23.2 1.9 42.3 477 竹村達 54.0 盛本信',
#  '2019/01/17 園田 12',
#  'Ｂ２Ｂ２\u3000４歳以上特別',
#  '',
#  '[過去映像]',
#  'ダ1230 良',
#  '晴 2 11 12/12 1:22.3 1.6 40.5 472 竹村達 54.0 盛本信',
#  '2018/12/30 園田 10',
#  'Ｂ２Ｂ２\u3000３歳以上特別',
#  '',
#  '[過去映像]',
#  'ダ1400 稍重',
# ...

# %%
elem_rankingBox=browser.find_elements_by_class_name('detailField')
elem_title=elem_rankingBox.find_elements_by_class_name('horseHistory ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1a728abd8b21> in <module>()
#       1 elem_rankingBox=browser.find_elements_by_class_name('detailField')
# ----> 2 elem_title=elem_rankingBox.find_elements_by_class_name('horseHistory ')
#
# AttributeError: 'list' object has no attribute 'find_elements_by_class_name'

# %%
elem_rankingBox=browser.find_elements_by_class_name(' ')
elem_rankingBox
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-56-d2c4a61f48e4> in <module>()
# ----> 1 elem_rankingBox=browser.find_elements_by_class_name(' ')
#       2 elem_rankingBox
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_class_name(self, name)
#     578             elements = driver.find_elements_by_class_name('foo')
#     579         """
# --> 580         return self.find_elements(by=By.CLASS_NAME, value=name)
#     581
#     582     def find_element_by_css_selector(self, css_selector):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
# -> 1007             'value': value})['value'] or []
#    1008
#    1009     @property
#
# ...

# %%
elem_title=elem_rankingBox.find_element_by_class_name(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-6567316d51d5> in <module>()
# ----> 1 elem_title=elem_rankingBox.find_element_by_class_name(' ')
#
# AttributeError: 'list' object has no attribute 'find_element_by_class_name'

# %%
title=elem_title

# %%
title
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="746e08a5b60bef4de8d0288b333b2dbb", element="0.24022383189184682-36")>]

# %%
title.split('\n')[1]
# Out:
# ''

# %%
elem=browser.find_element_by_class_name('u_rankBox')
elem=elem.find_element_by_class_name('evaluateNumber')

# %%
elem.text
# Out:
# '4.7'

# %% [markdown]
# #まとめて抽出

# %%
elem_rankingBox=browser.find_element_by_class_name('u_areaListRankingBox')
elem_title=elem_rankingBox.find_element_by_class_name('u_title').find_element_by_tag_name('h2')
elem_title.text
# Out:
# '1\n観光地 1'

# %%
elems_rankingBox=browser.find_elements_by_class_name('u_areaListRankingBox')

# %%
len(elems_rankingBox)
# Out:
# 10

# %%
elems_rankingBox=browser.find_elements_by_class_name('u_areaListRankingBox')
#すべての観光地名を観光地名を格納するリストtitlesを用意
titles=[]
for elem_rankingBox in elems_rankingBox:

#elem_rankingBox=elems_rankingBox[0]
    elem_title=elem_rankingBox.find_element_by_class_name('u_title')
    title=elem_title.text.split('\n')[1]
    titles.append(title)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10']

# %% [markdown]
# ###各項目の評価

# %%
elems = browser.find_elements_by_class_name('u_categoryTipsItem')

# %%
categories = []

for elem in elems:
        items = []
        elems_rank = elem.find_elements_by_class_name('is_rank')
        for elem_rank in elems_rank:
            rank = elem_rank.find_element_by_class_name('evaluateNumber').text
            items.append(float(rank))
        categories.append(items)

# %%
categories
# Out:
# [[4.6, 4.5, 4.9, 4.2],
#  [4.6, 4.5, 4.9, 4.2],
#  [4.5, 4.4, 4.8, 4.1],
#  [4.4, 4.4, 4.8, 4.0],
#  [4.4, 4.3, 4.7, 4.0],
#  [4.3, 4.3, 4.7, 3.9],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.1, 4.1, 4.5, 3.7],
#  [4.0, 4.1, 4.4, 3.6]]

# %% [markdown]
# ### 総合評価

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')

# %%
ranks = []
for elem_rank in elems_rank:
    elem_rank = elem_rank.find_element_by_class_name('evaluateNumber')
    rank = float(elem_rank.text)
    ranks.append(rank)

# %% [markdown]
# ### PANDASの形式に変換

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['観光地名'] = titles
df['総合評価'] = ranks

# %%
df
# Out:
#      観光地名  総合評価
# 0   観光地 1   4.7
# 1   観光地 2   4.7
# 2   観光地 3   4.6
# 3   観光地 4   4.5
# 4   観光地 5   4.5
# 5   観光地 6   4.4
# 6   観光地 7   4.3
# 7   観光地 8   4.3
# 8   観光地 9   4.2
# 9  観光地 10   4.1

# %%
df_categories = pd.DataFrame(categories)
df_categories
# Out:
#      0    1    2    3
# 0  4.6  4.5  4.9  4.2
# 1  4.6  4.5  4.9  4.2
# 2  4.5  4.4  4.8  4.1
# 3  4.4  4.4  4.8  4.0
# 4  4.4  4.3  4.7  4.0
# 5  4.3  4.3  4.7  3.9
# 6  4.2  4.2  4.6  3.8
# 7  4.2  4.2  4.6  3.8
# 8  4.1  4.1  4.5  3.7
# 9  4.0  4.1  4.4  3.6

# %%
df_categories.columns = ['楽しさ', '人混みの多さ', '景色', 'アクセス']
df_categories
# Out:
#    楽しさ  人混みの多さ   景色  アクセス
# 0  4.6     4.5  4.9   4.2
# 1  4.6     4.5  4.9   4.2
# 2  4.5     4.4  4.8   4.1
# 3  4.4     4.4  4.8   4.0
# 4  4.4     4.3  4.7   4.0
# 5  4.3     4.3  4.7   3.9
# 6  4.2     4.2  4.6   3.8
# 7  4.2     4.2  4.6   3.8
# 8  4.1     4.1  4.5   3.7
# 9  4.0     4.1  4.4   3.6

# %%
df = pd.concat([df, df_categories], axis=1)

# %%
df
# Out:
#      観光地名  総合評価  楽しさ  人混みの多さ   景色  アクセス  楽しさ  人混みの多さ   景色  アクセス
# 0   観光地 1   4.7  4.6     4.5  4.9   4.2  4.6     4.5  4.9   4.2
# 1   観光地 2   4.7  4.6     4.5  4.9   4.2  4.6     4.5  4.9   4.2
# 2   観光地 3   4.6  4.5     4.4  4.8   4.1  4.5     4.4  4.8   4.1
# 3   観光地 4   4.5  4.4     4.4  4.8   4.0  4.4     4.4  4.8   4.0
# 4   観光地 5   4.5  4.4     4.3  4.7   4.0  4.4     4.3  4.7   4.0
# 5   観光地 6   4.4  4.3     4.3  4.7   3.9  4.3     4.3  4.7   3.9
# 6   観光地 7   4.3  4.2     4.2  4.6   3.8  4.2     4.2  4.6   3.8
# 7   観光地 8   4.3  4.2     4.2  4.6   3.8  4.2     4.2  4.6   3.8
# 8   観光地 9   4.2  4.1     4.1  4.5   3.7  4.1     4.1  4.5   3.7
# 9  観光地 10   4.1  4.0     4.1  4.4   3.6  4.0     4.1  4.4   3.6

# %%
df.to_csv('観光地情報.csv', index=False)

# %% [markdown]
# ### 前頁の取得

# %% [markdown]
# - 観光地名
# - 総合評価
# - 各項目

# %%
'https://scraping-for-beginner.herokuapp.com/ranking/?page={}'.format(1)
# Out:
# 'https://scraping-for-beginner.herokuapp.com/ranking/?page=1'

# %%
pagination = browser.find_element_by_id('pagination')

# %%
page1 = pagination.find_elements_by_tag_name('li')[1]

# %%
page1.find_element_by_tag_name('a').click()

# %%
titles = []
ranks = []
categories = []

browser = webdriver.Chrome()

for page in range(1,4):

    browser.get('https://scraping-for-beginner.herokuapp.com/ranking/?page={}'.format(page))

    # 観光地名
    elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
    for elem_rankingBox in elems_rankingBox:
        elem_title = elem_rankingBox.find_element_by_class_name('u_title')
        title = elem_title.text.split('\n')[1]
        titles.append(title)

    # 総合評価
    elems_rank = browser.find_elements_by_class_name('u_rankBox')
    for elem_rank in elems_rank:
        elem_rank = elem_rank.find_element_by_class_name('evaluateNumber')
        rank = float(elem_rank.text)
        ranks.append(rank)

    # 各項目
    elems = browser.find_elements_by_class_name('u_categoryTipsItem')
    for elem in elems:
            items = []
            elems_rank = elem.find_elements_by_class_name('is_rank')
            for elem_rank in elems_rank:
                rank = elem_rank.find_element_by_class_name('evaluateNumber').text
                items.append(rank)
            categories.append(items)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10',
#  '観光地 11',
#  '観光地 12',
#  '観光地 13',
#  '観光地 14',
#  '観光地 15',
#  '観光地 16',
#  '観光地 17',
#  '観光地 18',
#  '観光地 19',
#  '観光地 20',
#  '観光地 21',
#  '観光地 22',
#  '観光地 23',
#  '観光地 24',
#  '観光地 25',
#  '観光地 26',
#  '観光地 27',
#  '観光地 28',
#  '観光地 29',
#  '観光地 30']

# %%
ranks
# Out:
# [4.7,
#  4.7,
#  4.6,
#  4.5,
#  4.5,
#  4.4,
#  4.3,
#  4.3,
#  4.2,
#  4.1,
#  4.1,
#  4.0,
#  3.9,
#  3.9,
#  3.8,
#  3.7,
#  3.7,
#  3.6,
#  3.5,
#  3.5,
#  3.4,
#  3.3,
#  3.3,
#  3.2,
#  3.1,
#  3.1,
#  3.0,
#  2.9,
#  2.9,
#  2.8]

# %%
categories
# Out:
# [['4.6', '4.5', '4.9', '4.2'],
#  ['4.6', '4.5', '4.9', '4.2'],
#  ['4.5', '4.4', '4.8', '4.1'],
#  ['4.4', '4.4', '4.8', '4.0'],
#  ['4.4', '4.3', '4.7', '4.0'],
#  ['4.3', '4.3', '4.7', '3.9'],
#  ['4.2', '4.2', '4.6', '3.8'],
#  ['4.2', '4.2', '4.6', '3.8'],
#  ['4.1', '4.1', '4.5', '3.7'],
#  ['4.0', '4.1', '4.4', '3.6'],
#  ['4.0', '4.0', '4.4', '3.6'],
#  ['3.9', '4.0', '4.3', '3.5'],
#  ['3.8', '3.9', '4.3', '3.4'],
#  ['3.8', '3.9', '4.2', '3.4'],
#  ['3.7', '3.8', '4.2', '3.3'],
#  ['3.6', '3.8', '4.1', '3.2'],
#  ['3.6', '3.7', '4.1', '3.2'],
#  ['3.5', '3.7', '4.0', '3.1'],
#  ['3.4', '3.6', '3.9', '3.0'],
#  ['3.4', '3.6', '3.9', '3.0'],
#  ['3.3', '3.5', '3.8', '2.9'],
#  ['3.2', '3.5', '3.8', '2.8'],
#  ['3.2', '3.4', '3.7', '2.8'],
#  ['3.1', '3.4', '3.7', '2.7'],
#  ['3.0', '3.3', '3.6', '2.6'],
#  ['3.0', '3.3', '3.6', '2.6'],
#  ['2.9', '3.2', '3.5', '2.5'],
#  ['2.8', '3.2', '3.4', '2.4'],
#  ['2.8', '3.1', '3.4', '2.4'],
#  ['2.7', '3.1', '3.3', '2.3']]

# %%
df = pd.DataFrame()

# %%
df['観光地名'] = titles
df['総合評価'] = ranks

# %%
df_categories = pd.DataFrame(categories)
df_categories
# Out:
#       0    1    2    3
# 0   4.6  4.5  4.9  4.2
# 1   4.6  4.5  4.9  4.2
# 2   4.5  4.4  4.8  4.1
# 3   4.4  4.4  4.8  4.0
# 4   4.4  4.3  4.7  4.0
# 5   4.3  4.3  4.7  3.9
# 6   4.2  4.2  4.6  3.8
# 7   4.2  4.2  4.6  3.8
# 8   4.1  4.1  4.5  3.7
# 9   4.0  4.1  4.4  3.6
# 10  4.0  4.0  4.4  3.6
# 11  3.9  4.0  4.3  3.5
# 12  3.8  3.9  4.3  3.4
# 13  3.8  3.9  4.2  3.4
# 14  3.7  3.8  4.2  3.3
# 15  3.6  3.8  4.1  3.2
# 16  3.6  3.7  4.1  3.2
# 17  3.5  3.7  4.0  3.1
# 18  3.4  3.6  3.9  3.0
# 19  3.4  3.6  3.9  3.0
# 20  3.3  3.5  3.8  2.9
# 21  3.2  3.5  3.8  2.8
# 22  3.2  3.4  3.7  2.8
# 23  3.1  3.4  3.7  2.7
# 24  3.0  3.3  3.6  2.6
# 25  3.0  3.3  3.6  2.6
# 26  2.9  3.2  3.5  2.5
# 27  2.8  3.2  3.4  2.4
# 28  2.8  3.1  3.4  2.4
# 29  2.7  3.1  3.3  2.3

# %%
df_categories.columns = ['楽しさ', '人混みの多さ', '景色', 'アクセス']
df_categories
# Out:
#     楽しさ 人混みの多さ   景色 アクセス
# 0   4.6    4.5  4.9  4.2
# 1   4.6    4.5  4.9  4.2
# 2   4.5    4.4  4.8  4.1
# 3   4.4    4.4  4.8  4.0
# 4   4.4    4.3  4.7  4.0
# 5   4.3    4.3  4.7  3.9
# 6   4.2    4.2  4.6  3.8
# 7   4.2    4.2  4.6  3.8
# 8   4.1    4.1  4.5  3.7
# 9   4.0    4.1  4.4  3.6
# 10  4.0    4.0  4.4  3.6
# 11  3.9    4.0  4.3  3.5
# 12  3.8    3.9  4.3  3.4
# 13  3.8    3.9  4.2  3.4
# 14  3.7    3.8  4.2  3.3
# 15  3.6    3.8  4.1  3.2
# 16  3.6    3.7  4.1  3.2
# 17  3.5    3.7  4.0  3.1
# 18  3.4    3.6  3.9  3.0
# 19  3.4    3.6  3.9  3.0
# 20  3.3    3.5  3.8  2.9
# 21  3.2    3.5  3.8  2.8
# 22  3.2    3.4  3.7  2.8
# 23  3.1    3.4  3.7  2.7
# 24  3.0    3.3  3.6  2.6
# 25  3.0    3.3  3.6  2.6
# 26  2.9    3.2  3.5  2.5
# 27  2.8    3.2  3.4  2.4
# 28  2.8    3.1  3.4  2.4
# 29  2.7    3.1  3.3  2.3

# %%
df = pd.concat([df, df_categories], axis=1)

# %%
df
# Out:
#       観光地名  総合評価  楽しさ 人混みの多さ   景色 アクセス
# 0    観光地 1   4.7  4.6    4.5  4.9  4.2
# 1    観光地 2   4.7  4.6    4.5  4.9  4.2
# 2    観光地 3   4.6  4.5    4.4  4.8  4.1
# 3    観光地 4   4.5  4.4    4.4  4.8  4.0
# 4    観光地 5   4.5  4.4    4.3  4.7  4.0
# 5    観光地 6   4.4  4.3    4.3  4.7  3.9
# 6    観光地 7   4.3  4.2    4.2  4.6  3.8
# 7    観光地 8   4.3  4.2    4.2  4.6  3.8
# 8    観光地 9   4.2  4.1    4.1  4.5  3.7
# 9   観光地 10   4.1  4.0    4.1  4.4  3.6
# 10  観光地 11   4.1  4.0    4.0  4.4  3.6
# 11  観光地 12   4.0  3.9    4.0  4.3  3.5
# 12  観光地 13   3.9  3.8    3.9  4.3  3.4
# 13  観光地 14   3.9  3.8    3.9  4.2  3.4
# 14  観光地 15   3.8  3.7    3.8  4.2  3.3
# 15  観光地 16   3.7  3.6    3.8  4.1  3.2
# 16  観光地 17   3.7  3.6    3.7  4.1  3.2
# 17  観光地 18   3.6  3.5    3.7  4.0  3.1
# 18  観光地 19   3.5  3.4    3.6  3.9  3.0
# 19  観光地 20   3.5  3.4    3.6  3.9  3.0
# 20  観光地 21   3.4  3.3    3.5  3.8  2.9
# 21  観光地 22   3.3  3.2    3.5  3.8  2.8
# 22  観光地 23   3.3  3.2    3.4  3.7  2.8
# ...

# %%
# -*- coding: utf-8 -*- 

import urllib.request
import codecs
import time
from datetime import datetime as dt
from collections import Counter
from bs4 import BeautifulSoup
import pandas
import re

for m in range(4,5):
    cal_html=urllib.request.urlopen("http://keiba.rakuten.co.jp/calendar?l-id=top_headernavi_2nd_calendar&tYear=2016&tMonth="+str(m))
    
    cal_soup = BeautifulSoup(cal_html,"lxml")
    
    for atag in cal_soup.find_all("a",href=re.compile("race_card/list/RACEID/2016.*0$")):
        race_src=atag.get("href")
        result_src=re.sub("race_card","race_performance",race_src)
        result_URL="http://keiba.rakuten.co.jp"+str(result_src)
        for race_list in ["01","02","03","04","05","06","07","08","09","10","11","12"]:
            race_URL=re.sub(r'00$',str(race_list),result_URL)
            race_html=urllib.request.urlopen(race_URL)
            race_soup=BeautifulSoup(race_html,"lxml")

            # 日付の取得
            race_date_raw=result_src[30:38]
            race_date=dt.strptime(race_date_raw,"%Y%m%d")

            # 競馬場名の取得
            course_name_elem=race_soup.find_all("span",class_="racePlace")
            course_name_raw=re.sub(r"<[^>]*?>","",str(course_name_elem))
            course_name=re.sub(r"[\[\]]","",str(course_name_raw))

            # レース番号の取得
            race_no_elem=race_soup.find_all("span",class_="num")
            race_no=race_list

            # 距離の取得
            distance_elem=race_soup.find_all("li",class_="distance")
            distance_raw=re.sub(r"<[^>]*?>","",str(distance_elem))
            distance=re.sub(r"[ダ芝,m\[\]]","",str(distance_raw))
            distance=re.sub(r"\(.\)","",str(distance))

            # 1着賞金の取得
            main_prize_elem=race_soup.find_all("li",text=re.compile("1着"))
            main_prize_raw=re.sub(r"<[^>]*?>","",str(main_prize_elem))
            main_prize=re.sub(",","",main_prize_raw[3:len(main_prize_raw)-2])

            # 馬場状態の取得
            course_cond_elem=race_soup.find_all("dd")
            course_cond=re.sub(r"<[^>]*?>","",str(course_cond_elem[1]))

            # コースの取得（盛岡に芝があるので）
            course_type=distance_raw[1]

            # 馬名の取得
            horse_name_elem=race_soup.find_all("td",class_="horse")

            # 年齢・毛色の取得
            horse_age_elem=race_soup.find_all("td",class_="state")

            # 馬番の取得
            horse_number_elem=race_soup.find_all("td",class_="number")

            # 着順の取得
            horse_order_elem=race_soup.find_all("td",class_="order")

            # 斤量の取得
            horse_weightTax_elem=race_soup.find_all("td",class_="weightTax")

            # 馬体重の取得
            horse_weight_elem=race_soup.find_all("td",class_="weight")
 
            # 騎手名の取得
            jockey_elem=race_soup.find_all("td",class_="jockey")

            # タイムの取得
            horse_time_elem=race_soup.find_all("td",class_="time")

            # 上がり3Fの取得
            horse_3F_elem=race_soup.find_all("td",class_="spurt")

            # 調教師名の取得
            trainer_elem=race_soup.find_all("td",class_="tamer")

            # 人気の取得
            horse_rank_elem=race_soup.find_all("td",class_="rank")

            # 頭数の算出
            num_horses=len(horse_name_elem)

            for i in range(num_horses):

                horse_name=re.sub(r"<[^>]*?>","",str(horse_name_elem[i]))

                horse_age_raw=re.sub(r"<[^>]*?>","",str(horse_age_elem[i]))

                horse_sex=re.sub(r"[^牡牝セ]","",horse_age_raw)

                horse_age=re.sub(r"[^0-9]","",horse_age_raw)

                horse_color=re.sub(r".*/","",horse_age_raw)
                
                horse_number=re.sub(r"<[^>]*?>","",str(horse_number_elem[i]))
                
                horse_order=re.sub(r"<[^>]*?>","",str(horse_order_elem[i]))
                if horse_order == "-":
                    horse_order=""
                
                horse_weightTax=re.sub(r"<[^>]*?>","",str(horse_weightTax_elem[i]))
                
                horse_weight_raw=re.sub(r"<[^>]*?>","",str(horse_weight_elem[i]))

                tmp=re.search(r"\+.*|-.*|±.*",str(horse_weight_raw))
                if tmp is not None:
                    horse_weight_change_raw=tmp.group(0)
                    horse_weight_change=re.sub(r"\+|±","",str(horse_weight_change_raw))
                else:
                    horse_weight_change=""

                if horse_weight_raw == "-\n":
                    horse_weight=""
                    horse_weight_change=""
                else:
                    horse_weight=re.sub(r"\+.*|-.*|±.*","",str(horse_weight_raw))

                jockey_raw=re.sub(r"<[^>]*?>","",str(jockey_elem[i]))
                jockey=re.sub(r"[\n☆★△▲]","",str(jockey_raw))
                
                horse_time_raw=re.sub(r"<[^>]*?>","",str(horse_time_elem[i]))
                counter=Counter(str(horse_time_raw))
                if horse_time_raw == "-":
                    horse_time=""
                    horse_time_sec=""
                else:
                    if counter[':'] == 0:
                        horse_time_orig=re.sub(r"$","0",str(horse_time_raw))
                        horse_time=dt.strptime(horse_time_orig,"%S.%f")
                        # タイム差を計算しやすくするため秒に変換
                        horse_time_sec=(horse_time.second+(horse_time.microsecond/1000000))
                    else:
                        horse_time_orig=re.sub(r"^|$","0",str(horse_time_raw))
                        horse_time=dt.strptime(horse_time_orig,"%M:%S.%f")
                        # タイム差を計算しやすくするため秒に変換
                        horse_time_sec=(horse_time.minute*60)+horse_time.second+(horse_time.microsecond/1000000)

                horse_3F_raw=re.sub(r"<[^>]*?>","",str(horse_3F_elem[i]))
                # ばんえいの上り3Fは存在しないので
                horse_3F=re.sub("-","",str(horse_3F_raw))
                
                trainer=re.sub(r"<[^>]*?>","",str(trainer_elem[i]))
                
                horse_rank_raw=re.sub(r"<[^>]*?>","",str(horse_rank_elem[i]))
                horse_rank=re.sub("-","",str(horse_rank_raw))

                # オッズの取得
                if course_name=="帯広ば":
                    n_course=65
                elif course_name=="門別":
                    n_course=30
                elif course_name=="盛岡":
                    n_course=35
                elif course_name=="水沢":
                    n_course=36
                elif course_name=="浦和":
                    n_course=42
                elif course_name=="船橋":
                    n_course=43
                elif course_name=="大井":
                    n_course=44
                elif course_name=="川崎":
                    n_course=45
                elif course_name=="金沢":
                    n_course=46
                elif course_name=="笠松":
                    n_course=47
                elif course_name=="名古屋":
                    n_course=48
                elif course_name=="園田":
                    n_course=50
                elif course_name=="姫路":
                    n_course=51
                elif course_name=="福山":
                    n_course=53
                elif course_name=="高知":
                    n_course=54
                elif course_name=="佐賀":
                    n_course=55
                elif course_name=="荒尾":
                    n_course=56

#                odds_url="http://db.netkeiba.com/race/"+str(race_date.year)+str(n_course)+str(race_date.month).rjust(2,"0")+str(race_date.day).rjust(2,"0")+str(race_no).rjust(2,"0")
                odds_url="http://nar.netkeiba.com/?pid=race&mode=result&id=c"+str(race_date.year)+str(n_course)+str(race_date.month).rjust(2,"0")+str(race_date.day).rjust(2,"0")+str(race_no).rjust(2,"0")
                odds_df=pandas.io.html.read_html(odds_url)
                odds_popularity=odds_df[0][9][1:]
                odds=odds_df[0][10][1:]

                print(str(dt.strftime(race_date,"%Y-%m-%d"))+","+course_name+","+race_no+","+course_type+","+distance+","+course_cond+","+main_prize+","+horse_order+","+horse_number+","+horse_name+","+horse_sex+","+horse_age+","+horse_color+","+horse_weightTax+","+jockey+","+horse_weight+","+horse_weight_change+","+str(horse_time_sec)+","+horse_3F+","+trainer+","+str(odds_popularity[i+1])+","+str(odds[i+1]))
                
                out=codecs.open("./nar_race_result_2016.csv","a","utf-8")
                out.write(str(dt.strftime(race_date,"%Y-%m-%d"))+","+course_name+","+race_no+","+course_type+","+distance+","+course_cond+","+main_prize+","+horse_order+","+horse_number+","+horse_name+","+horse_sex+","+horse_age+","+horse_color+","+horse_weightTax+","+jockey+","+horse_weight+","+horse_weight_change+","+str(horse_time_sec)+","+horse_3F+","+trainer+","+str(odds_popularity[i+1])+","+str(odds[i+1])+"\n")
                out.close()

#        time.sleep(1)
